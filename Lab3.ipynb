# %%
# !pip download pandas
# !pip download numpy
# !pip download matplotlib
# !pip download seaborn
# !pip download scikit-learn
# Out:
# Collecting pandas
#   File was already downloaded /content/pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# Collecting numpy>=1.26.0 (from pandas)
#   File was already downloaded /content/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting python-dateutil>=2.8.2 (from pandas)
#   File was already downloaded /content/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Collecting pytz>=2020.1 (from pandas)
#   File was already downloaded /content/pytz-2025.2-py2.py3-none-any.whl
# Collecting tzdata>=2022.7 (from pandas)
#   File was already downloaded /content/tzdata-2025.2-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   File was already downloaded /content/six-1.17.0-py2.py3-none-any.whl
# Successfully downloaded pandas numpy python-dateutil pytz tzdata six
# Collecting numpy
#   File was already downloaded /content/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Successfully downloaded numpy
# Collecting matplotlib
#   File was already downloaded /content/matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Collecting contourpy>=1.0.1 (from matplotlib)
#   File was already downloaded /content/contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting cycler>=0.10 (from matplotlib)
#   File was already downloaded /content/cycler-0.12.1-py3-none-any.whl
# Collecting fonttools>=4.22.0 (from matplotlib)
#   File was already downloaded /content/fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   File was already downloaded /content/kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Collecting numpy>=1.23 (from matplotlib)
#   File was already downloaded /content/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting packaging>=20.0 (from matplotlib)
#   File was already downloaded /content/packaging-25.0-py3-none-any.whl
# Collecting pillow>=8 (from matplotlib)
#   File was already downloaded /content/pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting pyparsing>=3 (from matplotlib)
#   File was already downloaded /content/pyparsing-3.2.5-py3-none-any.whl
# Collecting python-dateutil>=2.7 (from matplotlib)
#   File was already downloaded /content/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   File was already downloaded /content/six-1.17.0-py2.py3-none-any.whl
# Successfully downloaded matplotlib contourpy cycler fonttools kiwisolver numpy packaging pillow pyparsing python-dateutil six
# Collecting seaborn
#   File was already downloaded /content/seaborn-0.13.2-py3-none-any.whl
# Collecting numpy!=1.24.0,>=1.20 (from seaborn)
#   File was already downloaded /content/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting pandas>=1.2 (from seaborn)
#   File was already downloaded /content/pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   File was already downloaded /content/matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/cycler-0.12.1-py3-none-any.whl
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Collecting packaging>=20.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/packaging-25.0-py3-none-any.whl
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/pyparsing-3.2.5-py3-none-any.whl
# Collecting python-dateutil>=2.7 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   File was already downloaded /content/pytz-2025.2-py2.py3-none-any.whl
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   File was already downloaded /content/tzdata-2025.2-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn)
#   File was already downloaded /content/six-1.17.0-py2.py3-none-any.whl
# Successfully downloaded seaborn matplotlib numpy pandas contourpy cycler fonttools kiwisolver packaging pillow pyparsing python-dateutil pytz tzdata six
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   File was already downloaded /content/numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 83.2 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 19.1 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 31.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Saved ./scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Saved ./joblib-1.5.2-py3-none-any.whl
# Saved ./scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Saved ./threadpoolctl-3.6.0-py3-none-any.whl
# Successfully downloaded scikit-learn joblib numpy scipy threadpoolctl

# %%
# -----------------------------
# Name: Suryakant Upadhyay
# PRN: 20220802043
# -----------------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load & preprocess
df = pd.read_csv('/content/sample_data/winners_f1_1950_2025_v2.csv')

# 'continent' is the sensitive attribute for group fairness analysis
# 'team' column is used to define favorable outcome as winning with Ferrari
# "favorable" column = 1 if team is Ferrari, else 0
df['favorable'] = (df['team'] == 'Ferrari').astype(int)

sensitive = 'continent'
outcome = 'favorable'  # binary variable indicating Ferrari wins (favorable)

def fairness_metrics(data, s=sensitive, y=outcome):
    # g1 = outcome values for first group in sensitive attribute
    # g0 = outcome values for all other groups
    g1, g0 = data[data[s] == data[s].unique()[0]][y], data[data[s] != data[s].unique()[0]][y]
    return {
        "Demographic Parity Diff": abs(g1.mean() - g0.mean()),  # difference in favorable outcome rates
        "Disparate Impact Ratio": g0.mean() / g1.mean() if g1.mean() > 0 else 0,  # ratio < 1 suggests bias
        "Equal Opportunity Diff": abs(g1.mean() - g0.mean())  # same as Dem Parity Diff here
    }

# Before mitigation printout and plot: shows Ferrari win disparity by continent
print("📊 Before Mitigation:", fairness_metrics(df))
sns.barplot(x=df[sensitive], y=df[outcome])
plt.title(f"Ferrari Win Rate by {sensitive} (Before)")
plt.show()

# Mitigation: balance dataset by oversampling minority continent groups
majority_grp = df[sensitive].value_counts().idxmax()
df_majority = df[df[sensitive] == majority_grp]
df_minority = df[df[sensitive] != majority_grp]
df_minority_upsampled = df_minority.sample(n=len(df_majority), replace=True, random_state=42)
df_bal = pd.concat([df_majority, df_minority_upsampled])

# Train logistic regression model on balanced data
X_train, X_test, y_train, y_test = train_test_split(df_bal.drop(columns=[outcome]), df_bal[outcome], test_size=0.3, random_state=42)
model = LogisticRegression(max_iter=1000)
model.fit(X_train.select_dtypes(include=[np.number]), y_train)
y_pred = model.predict(X_test.select_dtypes(include=[np.number]))
acc = accuracy_score(y_test, y_pred)
print("\n✅ Model Accuracy After Mitigation:", acc)

# After mitigation printout and plot
print("\n📊 After Mitigation:", fairness_metrics(df_bal))
sns.barplot(x=df_bal[sensitive], y=df_bal[outcome])
plt.title(f"Ferrari Win Rate by {sensitive} (After)")
plt.show()

# Comparison of fairness metrics before vs after mitigation
comparison = pd.DataFrame([fairness_metrics(df), fairness_metrics(df_bal)], index=["Before", "After"])
print("\n📈 Comparison:\n", comparison)
# Out:
# 📊 Before Mitigation: {'Demographic Parity Diff': np.float64(0.027108587796020683), 'Disparate Impact Ratio': np.float64(0.8815510112861772), 'Equal Opportunity Diff': np.float64(0.027108587796020683)}
# ✅ Model Accuracy After Mitigation: 0.7694174757281553
#
# 📊 After Mitigation: {'Demographic Parity Diff': np.float64(0.04081632653061226), 'Disparate Impact Ratio': np.float64(0.8216560509554139), 'Equal Opportunity Diff': np.float64(0.04081632653061226)}
# 📈 Comparison:
#          Demographic Parity Diff  Disparate Impact Ratio  \
# Before                 0.027109                0.881551
# After                  0.040816                0.821656
#
#         Equal Opportunity Diff
# Before                0.027109
# After                 0.040816
